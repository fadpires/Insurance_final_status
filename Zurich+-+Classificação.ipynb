# %%
import pandas as pd

zurich = pd.read_csv('/home/sbk2/Desktop/Zurich/Final/train1.csv', decimal=',', encoding='utf-8')
pd.options.display.float_format = '{:.2f}'.format
zurich.head(10)
# Out:
#     Ano Mês Encerramento Ramo Segmento                              Produto  \
# 0  2017            JULHO   82     LIFE  ACIDENTES PESSOAIS MENSAL SANTANDER
# 1  2014            JULHO   93     LIFE              VIDA PROTEÇÃO EXCLUSIVA
# 2  2015            ABRIL   82     LIFE  ACIDENTES PESSOAIS MENSAL SANTANDER
# 3  2016          OUTUBRO   93     LIFE        PROTEÇÃO VIDA EMPRESA - STYLE
# 4  2017           AGOSTO   82     LIFE                RIDERS REAL VIDA / AP
# 5  2017            JULHO   93     LIFE               MERIDIONAL CORRENTISTA
# 6  2017             MAIO   14       GI                 PROTEÇÃO RESIDENCIAL
# 7  2017          OUTUBRO   82     LIFE  ACIDENTES PESSOAIS MENSAL SANTANDER
# 8  2014         SETEMBRO   93     LIFE                             VIDAPREV
# 9  2015         SETEMBRO   14       GI        PROTEÇÃO RESIDENCIAL VAN GOGH
#
#    Código Produto                           Cobertura Reclamada  \
# 0         5012.00                                           IPA
# 1         5030.00     INVALIDEZ FUNCIONAL PERM. TOTAL P/ DOENÇA
# 2             nan                                         Morte
# 3         5081.00                                         MORTE
# 4         5101.00                                           IPA
# 5         5066.00                                 MORTE NATURAL
# 6         8106.00                                   ROUBO/FURTO
# 7         5012.00                               MORTE ACIDENTAL
# 8             nan  INVALIDEZ PERM. TOTAL OU PARCIAL P/ ACIDENTE
# 9             nan                                     Vendaval
#
#   Classificação Produto      Motivo da Ação  \
# 0                   Sim     SINISTRO NEGADO
# 1                   NaN     SINISTRO NEGADO
# 2                   NaN    Sinistro Negado
# 3                   NaN     Sinistro negado
# 4                   Não  SINISTRO LIQUIDADO
# 5                   Não  SINISTRO LIQUIDADO
# 6                   Sim     SINISTRO NEGADO
# 7                   Sim     SINISTRO NEGADO
# 8                   NaN     SINISTRO NEGADO
# 9                   NaN    Sinistro Negado
#
#                                    Motivo Seguradora     ...      \
# 0                                FALTA DE DOCUMENTOS     ...
# 1                              SEM COBERTURA TÉCNICA     ...
# 2                       Falta de pagamento do prêmio     ...
# 3                                Falta de documentos     ...
# 4                         Sinistro pago parcialmente     ...
# 5                         Sinistro pago parcialmente     ...
# 6  Caracteristica do imóvel ( Veraneio / Comercia...     ...
# 7                                FALTA DE DOCUMENTOS     ...
# 8                                FALTA DE DOCUMENTOS     ...
# 9        Vendaval / Desmoronamento não caracterizado     ...
#
#                               Motivo do Encerramento Valor do Encerramento  \
# 0  Extinção Art. 267 - Com Possibilidade Nova Açã...                     0
# 1                                  Procedência Total               R$ -
# 2               Improcedência da Ação - 1ª Instância                 R$ -
# 3  Extinção Art. 267 - Sem Possibilidade Nova Açã...                     0
# 4  Improcedência da Ação - 2ª Instância - Recurso...                     0
# 5                           Acordo antes da Sentença                     0
# 6                 Procedência Parcial - 1ª Instância                     0
# 7               Improcedência da Ação - 1ª Instância                     0
# 8                                Procedência Parcial               R$ -
# 9                           Acordo antes da Sentença                 R$ -
#
#               Nº do Dossiê  Data Distribuição        Data de En  \
# 0  02.02.507.0002335184/16         06-10-2016        12-10-2016
# 1  02.02.507.0000843428/09         25-03-2009  08-04-2009 11:26
# 2  02.02.507.0001163373/12         09-01-2012  19-01-2012 20:35
# 3  02.02.507.0002040354/14         13-10-2014        26-02-2015
# 4  02.02.507.0001764913/13         13-12-2013        19-12-2013
# 5  02.02.507.0002402397/16         29-11-2016        27-12-2016
# 6  02.02.136.0002304150/16         27-07-2016        18-08-2016
# 7  02.02.507.0002192902/15         17-12-2015        13-01-2016
# 8  02.02.507.0000652570/10         27-04-2010  18-05-2010 16:08
# 9  02.02.136.0002126689/15         30-06-2015   28-07-2015 1:54
#
#   ImportânciaSeguradaRestante Data Entrada Data do encerramento  Unnamed: 59  \
# 0                       53442   12-10-2016           31-07-2017          NaN
# 1                    25946,29   25-03-2009           02-07-2014          NaN
# 2                      250000   09-01-2012           09-04-2015          NaN
# 3                       60000   26-02-2015           18-10-2016          NaN
# 4                   113833,35   19-12-2013           01-08-2017          NaN
# 5                           0   27-12-2016           31-07-2017          NaN
# 6                       17500   18-08-2016           24-05-2017          NaN
# 7                       91638   13-01-2016           25-10-2017          NaN
# 8                    73120,38   27-04-2010           16-09-2014          NaN
# 9                       10000   30-06-2015           17-09-2015          NaN
#
#   Unnamed: 60
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
#
# [10 rows x 61 columns]

# %%
import numpy as np
zurich_categ = zurich[['Ano','Mês Encerramento','Segmento','Produto','Cobertura Reclamada','Motivo da Ação','Motivo Seguradora','Status Encerramento','Classificação da Contingência','Objeto']]
zurich_categ = zurich_categ.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)
zurich_categ = zurich_categ.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

zurich_categ.head(10)
# Out:
#     Ano Mês Encerramento Segmento                              Produto  \
# 0  2017            julho     life  acidentes pessoais mensal santander
# 1  2014            julho     life              vida proteção exclusiva
# 2  2015            abril     life  acidentes pessoais mensal santander
# 3  2016          outubro     life        proteção vida empresa - style
# 4  2017           agosto     life                riders real vida / ap
# 5  2017            julho     life               meridional correntista
# 6  2017             maio       gi                 proteção residencial
# 7  2017          outubro     life  acidentes pessoais mensal santander
# 8  2014         setembro     life                             vidaprev
# 9  2015         setembro       gi        proteção residencial van gogh
#
#                             Cobertura Reclamada      Motivo da Ação  \
# 0                                           ipa     sinistro negado
# 1     invalidez funcional perm. total p/ doença     sinistro negado
# 2                                         morte     sinistro negado
# 3                                         morte     sinistro negado
# 4                                           ipa  sinistro liquidado
# 5                                 morte natural  sinistro liquidado
# 6                                   roubo/furto     sinistro negado
# 7                               morte acidental     sinistro negado
# 8  invalidez perm. total ou parcial p/ acidente     sinistro negado
# 9                                      vendaval     sinistro negado
#
#                                    Motivo Seguradora  Status Encerramento  \
# 0                                falta de documentos       pagamento zero
# 1                              sem cobertura técnica    procedência total
# 2                       falta de pagamento do prêmio       pagamento zero
# 3                                falta de documentos       pagamento zero
# 4                         sinistro pago parcialmente       pagamento zero
# 5                         sinistro pago parcialmente               acordo
# 6  caracteristica do imóvel ( veraneio / comercia...  procedência parcial
# 7                                falta de documentos       pagamento zero
# 8                                falta de documentos  procedência parcial
# 9        vendaval / desmoronamento não caracterizado               acordo
#
#   Classificação da Contingência              Objeto
# 0                    condenação      seguro de vida
# 1                   sucumbência      seguro de vida
# 2                    condenação      seguro de vida
# 3                    condenação      seguro de vida
# 4                    condenação      seguro de vida
# 5                    condenação      seguro de vida
# 6                    condenação  seguro residencial
# 7                    condenação      seguro de vida
# 8                    condenação      seguro de vida
# 9                    condenação  seguro residencial

# %%
zurich_categ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3004 entries, 0 to 3003
# Data columns (total 10 columns):
# Ano                              3004 non-null int64
# Mês Encerramento                 3004 non-null object
# Segmento                         3004 non-null object
# Produto                          3000 non-null object
# Cobertura Reclamada              3003 non-null object
# Motivo da Ação                   3000 non-null object
# Motivo Seguradora                2983 non-null object
# Status Encerramento              3004 non-null object
# Classificação da Contingência    2916 non-null object
# Objeto                           2996 non-null object
# dtypes: int64(1), object(9)
# memory usage: 234.8+ KB

# %%
zurich_categ['Ano'].value_counts()
# Out:
# 2017    931
# 2015    822
# 2016    780
# 2014    471
# Name: Ano, dtype: int64

# %%
zurich_categ['Ano'] = zurich_categ['Ano'].replace(2014, 1)
zurich_categ['Ano'] = zurich_categ['Ano'].replace(2015, 2)
zurich_categ['Ano'] = zurich_categ['Ano'].replace(2016, 3)
zurich_categ['Ano'] = zurich_categ['Ano'].replace(2017, 4)

# %%
zurich_categ['Mês Encerramento'].value_counts()
# Out:
# outubro      368
# agosto       342
# maio         301
# julho        296
# junho        245
# setembro     225
# fevereiro    217
# novembro     210
# dezembro     205
# janeiro      203
# março        202
# abril        190
# Name: Mês Encerramento, dtype: int64

# %%
zurich_categ['Segmento'].value_counts()
# Out:
# life    2497
# gi       507
# Name: Segmento, dtype: int64

# %%
zurich_categ['Segmento'] = zurich_categ['Segmento'].replace('life', 1)
zurich_categ['Segmento'] = zurich_categ['Segmento'].replace('gi', 2)

# %%
zurich_categ['Produto'].value_counts()
# Out:
# vida proteção exclusiva                      485
# proteção vida empresa santander              331
# acidentes pessoais mensal santander          250
# produto genérico                             169
# residencial dose dupla                       116
# proteção residencial dose dupla              106
# apólice específica vg mensal                 105
# proteção residencial van gogh                102
# acidentes pessoais men santander              72
# vida master santander                         68
# santander protecao sob medida                 67
# protecao mulher men santander                 56
# protecao vida homem                           49
# acidentes pessoais an. santander              44
# proteção acidentes pessoais                   41
# proteção vida empresa - style                 39
# vida em grupo generico                        35
# residencial                                   32
# novo vida santander                           31
# ap mensal -  style                            30
# protecao vida van gogh                        29
# protecao vida premiada                        28
# proteção residencial sob medida               28
# proteção residencial                          26
# vida master                                   24
# meridional correntista                        23
# riders real vida / ap                         21
# seg vida santander mensal                     20
# proteção empresarial santander                20
# acidentes pessoais anual santander            20
#                                             ...
# prestamista cp santander                       1
# vida santander                                 1
# apólice específica vida  - style               1
# residencial telemarketing                      1
# prestamista empr folha santander               1
# proteção mulher sanatander                     1
# vida empresa style                             1
# ap aereo autom sb (cartoes)                    1
# 2014-93-60663-0                                1
# vgbl previdência especial renda fixa           1
# proteção especial - ap                         1
# seg vida clube mig style - mensal              1
# vida individual anual                          1
# proteção mulher mensal santander               1
# acidentes pessoais a n santander               1
# seguro vida migracao style                     1
# proteção vida protetor rural                   1
# apólice espcifica vg mensal - vida mensal      1
# proteção vida mulher                           1
# proteção vida empresa santande                 1
# apolice especifica - vida mensal               1
# proteção mulher santander (impl)               1
# protecao mulher mensal santander               1
# mrp familia prev                               1
# vem                                            1
# prestamista                                    1
# super multi 20 vgbl individual                 1
# sudameris vida homem                           1
# vida proteção                                  1
# santander prev vgb                             1
# Name: Produto, Length: 183, dtype: int64

# %%
zurich_categ['Cobertura Reclamada'].value_counts()
# Out:
# ipa                                             543
# ifpd                                            443
# morte natural                                   388
# morte                                           361
# morte acidental                                 307
# roubo/furto                                     249
# invalidez funcional perm. total p/ doença       124
# invalidez perm. total ou parcial p/ acidente    101
# vendaval                                         81
# danos elétricos                                  63
# desmoronamento                                   43
# incêndio                                         36
# diagnóstico de câncer                            34
# auxilio funeral                                  30
# diagnostico de cancer                            25
# morte conjuge                                    13
# auxílio funeral                                  12
# doencas graves                                   11
# doença terminal                                  10
# colisão de veículo                                9
# diagnóstico câncer                                9
# doença grave                                      8
# morte + auxílio funeral                           8
# diária de internação hospitalar                   8
# doenças graves                                    8
# pecúlio por morte                                 7
# invalidez por doença                              6
# pecúlio                                           6
# incendio raio explosão                            4
# internação hospitalar                             3
#                                                ...
# auto                                              3
# funeral                                           3
# responsabilidade civil                            3
# internação hospitalar por acidente                3
# perda e pagamento de aluguel                      3
# colisão, incêndio ou roubo                        3
# morte sócio                                       3
# pagamento de aluguel                              2
# morte natural filho                               2
# desemprego involuntário                           2
# dfi                                               2
# roubo de veículo                                  2
# quebra de vidros                                  2
# invalidez por aposentadoria                       1
# morte natural cônjuge                             1
# doença degenerativa                               1
# perda total de veículo                            1
# resgate da reserva técnica                        1
# morte natural + auxílio funeral                   1
# arrombamento                                      1
# tumulto                                           1
# quebra de vidro                                   1
# internação hospitalar por doença                  1
# incapacidade física temporária por acidente       1
# morte - filho funcionários                        1
# morte acidental + auxílio funeral                 1
# funeral familiar                                  1
# doença preexistente                               1
# danos físicos ao imóvel                           1
# morte - cônjuge                                   1
# Name: Cobertura Reclamada, Length: 61, dtype: int64

# %%
zurich_categ['Motivo da Ação'].value_counts()
# Out:
# sinistro negado                    2281
# sinistro liquidado parcialmente     303
# sinistro não avisado                233
# sinistro liquidado                  146
# indenização parcial                  24
# notificação sem regulação             7
# negado pré-analise                    4
# notificação não atendida              1
# ctg reportada.                        1
# Name: Motivo da Ação, dtype: int64

# %%
zurich_categ['Motivo da Ação'] = zurich_categ['Motivo da Ação'].replace('indenização parcial', 'sinistro liquidado parcialmente')
zurich_categ['Motivo da Ação'] = zurich_categ['Motivo da Ação'].replace(['notificação sem regulação','negado pré-analise','ctg reportada.','notificação não atendida'], 'outros')
zurich_categ['Motivo da Ação'] = zurich_categ['Motivo da Ação'].replace('sinistro negado', 1)
zurich_categ['Motivo da Ação'] = zurich_categ['Motivo da Ação'].replace('sinistro liquidado parcialmente', 2)
zurich_categ['Motivo da Ação'] = zurich_categ['Motivo da Ação'].replace('sinistro não avisado', 3)
zurich_categ['Motivo da Ação'] = zurich_categ['Motivo da Ação'].replace('sinistro liquidado', 4)
zurich_categ['Motivo da Ação'] = zurich_categ['Motivo da Ação'].replace('outros', 5)

# %%
zurich_categ['Motivo Seguradora'].value_counts()
# Out:
# sem caracterização de ifpd / ipa / doenças graves / preexistência             552
# falta de documentos                                                           510
# pagamento de acordo com comprovações/perícia                                  297
# limite de idade / nº mínimo segurados                                         254
# sinistro não avisado                                                          236
# ausência de cobertura                                                         163
# sinistro pago parcialmente                                                    135
# sem cobertura técnica                                                         124
# doença preexistente                                                            80
# risco excluído                                                                 65
# prescrição / carência                                                          63
# agravamento de risco / embriaguez                                              55
# falta de pagamento do prêmio                                                   50
# evento não caracterizado                                                       32
# imóvel (veraneio / comercial / desabitado)                                     29
# invalidez por doença não caracterizada                                         24
# vendaval / desmoronamento não caracterizado                                    24
# furto simples                                                                  23
# suicídio - art. 798, cc                                                        23
# bens não cobertos / comprovação preexistência                                  23
# sinistro liquidado parcialmente                                                23
# omissão na declaração de saúde                                                 21
# sinistro anterior ao início de vigência                                        19
# carência                                                                       16
# sem caracterização de ifdp                                                     16
# caracteristica do imóvel ( veraneio / comercial / desabitado / em reforma)     16
# pagamento de acordo com comprovações / perícia                                 15
# acima do limite de idade                                                       15
# prescrição                                                                     14
# falta de pagamento de prêmio                                                   11
# apólice cancelada/prêmio                                                        9
# agravamento de risco                                                            9
# ifpd não caracterizada                                                          6
# sem caracterização de ipa                                                       6
# erro operacional                                                                3
# sinistro liquidado                                                              3
# vendaval não caracterizado                                                      2
# prejuízo abaixo da franquia                                                     2
# ilegitimidade passiva                                                           1
# ausencia de comprovante dos bens                                                1
# sinistro anterior/posterior à vigencia                                          1
# suicídio - art. 798 cc                                                          1
# notificação não atendida na central                                             1
# atividade comercial                                                             1
# sinistro ocorrido antes da vigência da apólice                                  1
# doença terminal não caracterizada                                               1
# sinistro negado                                                                 1
# violação contratural                                                            1
# sinistro anterior ao inicío de vigência da apólice                              1
# sem contato com o segurado                                                      1
# não faz parte do grupo segurado                                                 1
# prática de ato ilícito                                                          1
# falta de verossimilhança entre os fatos                                         1
# Name: Motivo Seguradora, dtype: int64

# %%
zurich_categ['Status Encerramento'].value_counts()
# Out:
# acordo                 1088
# pagamento zero         1071
# procedência parcial     445
# procedência total       400
# Name: Status Encerramento, dtype: int64

# %%
zurich_categ['Classificação da Contingência'].value_counts()
# Out:
# condenação     2640
# sucumbência     273
# 0                 2
# remoto            1
# Name: Classificação da Contingência, dtype: int64

# %%
zurich_categ = zurich_categ[zurich_categ['Classificação da Contingência'] != 'remoto' ]
zurich_categ = zurich_categ[zurich_categ['Classificação da Contingência'] != '0' ]

# %%
zurich_categ['Classificação da Contingência'] = zurich_categ['Classificação da Contingência'].replace('condenação', 1)
zurich_categ['Classificação da Contingência'] = zurich_categ['Classificação da Contingência'].replace('sucumbência', 2)

# %%
zurich_categ['Objeto'].value_counts()
# Out:
# seguro de vida               2222
# seguro residencial            475
# acidentes pessoais            188
# seguro automóvel               23
# seguro prestamista             22
# seguro acidentes pessoais      19
# seguro de automóvel            15
# seguros diversos               15
# seguro empresarial              8
# previdência privada             5
# seguro de saúde                 1
# cartão de crédito               1
# Name: Objeto, dtype: int64

# %%
zurich_categ['Objeto'] = zurich_categ['Objeto'].replace('seguro acidentes pessoais', 'acidentes pessoais')
zurich_categ['Objeto'] = zurich_categ['Objeto'].replace('seguro de automóvel', 'seguro automóvel')
zurich_categ['Objeto'] = zurich_categ['Objeto'].replace(['cartão de crédito','seguro de saúde'], 'seguros diversos')
zurich_categ['Objeto'] = zurich_categ['Objeto'].replace(['seguro automóvel','seguro prestamista','seguro empresarial','previdência privada'], 'seguros diversos')

zurich_categ['Objeto'] = zurich_categ['Objeto'].replace('seguro de vida', 1)
zurich_categ['Objeto'] = zurich_categ['Objeto'].replace('seguro residencial', 2)
zurich_categ['Objeto'] = zurich_categ['Objeto'].replace('acidentes pessoais', 3)
zurich_categ['Objeto'] = zurich_categ['Objeto'].replace('seguros diversos', 4)

# %%
zurich_categ = zurich_categ.dropna()

# %%
zurich_categ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2884 entries, 0 to 3003
# Data columns (total 10 columns):
# Ano                              2884 non-null int64
# Mês Encerramento                 2884 non-null object
# Segmento                         2884 non-null int64
# Produto                          2884 non-null object
# Cobertura Reclamada              2884 non-null object
# Motivo da Ação                   2884 non-null float64
# Motivo Seguradora                2884 non-null object
# Status Encerramento              2884 non-null object
# Classificação da Contingência    2884 non-null float64
# Objeto                           2884 non-null float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 247.8+ KB

# %%
# from sklearn.model_selection import train_test_split
# train, test = train_test_split(zurich_categ, test_size=0.2)
# test.info()

# %%
features = list(zurich_categ.columns[1:7])
print("* features:", features, sep="\n")
# Out:
# * features:
# ['Mês Encerramento', 'Segmento', 'Produto', 'Cobertura Reclamada', 'Motivo da Ação', 'Motivo Seguradora']

# %%
# import pandas as pd
# from sklearn.preprocessing import LabelEncoder
# from sklearn.pipeline import Pipeline


# class MultiColumnLabelEncoder:
#     def __init__(self,columns = None):
#         self.columns = columns # array of column names to encode

#     def fit(self,X,y=None):
#         return self # not relevant here

#     def transform(self,X):
#         '''
#         Transforms columns of X specified in self.columns using
#         LabelEncoder(). If no columns specified, transforms all
#         columns in X.
#         '''
#         output = X.copy()
#         if self.columns is not None:
#             for col in self.columns:
#                 output[col] = LabelEncoder().fit_transform(output[col])
#         else:
#             for colname,col in output.iteritems():
#                 output[colname] = LabelEncoder().fit_transform(col)
#         return output

#     def fit_transform(self,X,y=None):
#         return self.fit(X,y).transform(X)

# %%
# from sklearn.preprocessing import LabelEncoder
# from sklearn import preprocessing

# le = preprocessing.LabelEncoder()

# le.fit(zurich_categ['Segmento'])

# list(le.classes_)

# le.transform(zurich_categ['Segmento'])

# %%
# zurich_mudado = MultiColumnLabelEncoder(columns = ['Segmento','Mês Encerramento', 'Motivo da Ação','Classificação da Contingência','Objeto']).fit_transform(zurich_categ)

# %%
zurich_categ.head(10)
# Out:
#    Ano Mês Encerramento  Segmento                              Produto  \
# 0    4            julho         1  acidentes pessoais mensal santander
# 1    1            julho         1              vida proteção exclusiva
# 2    2            abril         1  acidentes pessoais mensal santander
# 3    3          outubro         1        proteção vida empresa - style
# 4    4           agosto         1                riders real vida / ap
# 5    4            julho         1               meridional correntista
# 6    4             maio         2                 proteção residencial
# 7    4          outubro         1  acidentes pessoais mensal santander
# 8    1         setembro         1                             vidaprev
# 9    2         setembro         2        proteção residencial van gogh
#
#                             Cobertura Reclamada  Motivo da Ação  \
# 0                                           ipa            1.00
# 1     invalidez funcional perm. total p/ doença            1.00
# 2                                         morte            1.00
# 3                                         morte            1.00
# 4                                           ipa            4.00
# 5                                 morte natural            4.00
# 6                                   roubo/furto            1.00
# 7                               morte acidental            1.00
# 8  invalidez perm. total ou parcial p/ acidente            1.00
# 9                                      vendaval            1.00
#
#                                    Motivo Seguradora  Status Encerramento  \
# 0                                falta de documentos       pagamento zero
# 1                              sem cobertura técnica    procedência total
# 2                       falta de pagamento do prêmio       pagamento zero
# 3                                falta de documentos       pagamento zero
# 4                         sinistro pago parcialmente       pagamento zero
# 5                         sinistro pago parcialmente               acordo
# 6  caracteristica do imóvel ( veraneio / comercia...  procedência parcial
# 7                                falta de documentos       pagamento zero
# 8                                falta de documentos  procedência parcial
# 9        vendaval / desmoronamento não caracterizado               acordo
#
#    Classificação da Contingência  Objeto
# 0                           1.00    1.00
# 1                           2.00    1.00
# 2                           1.00    1.00
# 3                           1.00    1.00
# 4                           1.00    1.00
# 5                           1.00    1.00
# 6                           1.00    2.00
# 7                           1.00    1.00
# 8                           1.00    1.00
# 9                           1.00    2.00

# %%
zurich_categ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2884 entries, 0 to 3003
# Data columns (total 10 columns):
# Ano                              2884 non-null int64
# Mês Encerramento                 2884 non-null object
# Segmento                         2884 non-null int64
# Produto                          2884 non-null object
# Cobertura Reclamada              2884 non-null object
# Motivo da Ação                   2884 non-null float64
# Motivo Seguradora                2884 non-null object
# Status Encerramento              2884 non-null object
# Classificação da Contingência    2884 non-null float64
# Objeto                           2884 non-null float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 247.8+ KB

# %%
features_teste = list(zurich_categ.columns[[2,5,8,9]])
print("* features_teste:", features_teste, sep="\n")
# Out:
# * features_teste:
# ['Segmento', 'Motivo da Ação', 'Classificação da Contingência', 'Objeto']

# %%
def encode_target(df, target_column):

    df_mod = df.copy()
    targets = df_mod[target_column].unique()
    map_to_int = {name: n for n, name in enumerate(targets)}
    df_mod["Target"] = df_mod[target_column].replace(map_to_int)

    return (df_mod, targets)

# %%
zurich_categ_target, targets = encode_target(zurich_categ, "Status Encerramento")
print("* zurich_categ_target.head()", zurich_categ_target[["Target", "Status Encerramento"]].head(20),
      sep="\n", end="\n\n")
# Out:
# * zurich_categ_target.head()
#     Target  Status Encerramento
# 0        0       pagamento zero
# 1        1    procedência total
# 2        0       pagamento zero
# 3        0       pagamento zero
# 4        0       pagamento zero
# 5        2               acordo
# 6        3  procedência parcial
# 7        0       pagamento zero
# 8        3  procedência parcial
# 9        2               acordo
# 10       3  procedência parcial
# 11       0       pagamento zero
# 12       2               acordo
# 13       1    procedência total
# 14       0       pagamento zero
# 15       3  procedência parcial
# 16       2               acordo
# 17       2               acordo
# 18       0       pagamento zero
# 19       2               acordo

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz


y = zurich_categ_target["Target"]
X = zurich_categ_target[features_teste]
dt = DecisionTreeClassifier(min_samples_split=100, random_state=99)
dt.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=100,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=99,
#             splitter='best')

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
rf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=True, random_state=123456, verbose=0,
#             warm_start=False)

# %%
def visualize_tree(tree, feature_names):
    """Create tree png using graphviz.

    Args
    ----
    tree -- scikit-learn DecsisionTree.
    feature_names -- list of feature names.
    """
    with open("dt.dot", 'w') as f:
        export_graphviz(tree, out_file=f,
                        feature_names=feature_names)

    command = ["dot", "-Tpng", "dt.dot", "-o", "dt.png"]
    try:
        subprocess.check_call(command)
    except:
        exit("Could not run dot, ie graphviz, to "
             "produce visualization")

# %%
visualize_tree(dt, features_teste)

# %%
def get_code(tree, feature_names, target_names,
             spacer_base="    "):
    """Produce psuedo-code for decision tree.

    Args
    ----
    tree -- scikit-leant DescisionTree.
    feature_names -- list of feature names.
    target_names -- list of target (class) names.
    spacer_base -- used for spacing code (default: "    ").

    Notes
    -----
    based on http://stackoverflow.com/a/30104792.
    """
    left      = tree.tree_.children_left
    right     = tree.tree_.children_right
    threshold = tree.tree_.threshold
    features  = [feature_names[i] for i in tree.tree_.feature]
    value = tree.tree_.value

    def recurse(left, right, threshold, features, node, depth):
        spacer = spacer_base * depth
        if (threshold[node] != -2):
            print(spacer + "if ( " + features[node] + " <= " + \
                  str(threshold[node]) + " ) {")
            if left[node] != -1:
                    recurse(left, right, threshold, features,
                            left[node], depth+1)
            print(spacer + "}\n" + spacer +"else {")
            if right[node] != -1:
                    recurse(left, right, threshold, features,
                            right[node], depth+1)
            print(spacer + "}")
        else:
            target = value[node]
            for i, v in zip(np.nonzero(target)[1],
                            target[np.nonzero(target)]):
                target_name = target_names[i]
                target_count = int(v)
                print(spacer + "return " + str(target_name) + \
                      " ( " + str(target_count) + " examples )")

    recurse(left, right, threshold, features, 0, 0)

# %%
get_code(dt,features, targets)
# Out:
# if ( Produto <= 1.5 ) {
#     if ( Mês Encerramento <= 1.5 ) {
#         if ( Cobertura Reclamada <= 2.5 ) {
#             if ( Segmento <= 3.5 ) {
#                 if ( Segmento <= 2.5 ) {
#                     if ( Cobertura Reclamada <= 1.5 ) {
#                         if ( Segmento <= 1.5 ) {
#                             return pagamento zero ( 551 examples )
#                             return procedência total ( 172 examples )
#                             return acordo ( 594 examples )
#                             return procedência parcial ( 173 examples )
#                         }
#                         else {
#                             return pagamento zero ( 53 examples )
#                             return procedência total ( 14 examples )
#                             return acordo ( 51 examples )
#                             return procedência parcial ( 22 examples )
#                         }
#                     }
#                     else {
#                         return pagamento zero ( 2 examples )
#                         return procedência total ( 2 examples )
#                         return acordo ( 2 examples )
#                     }
#                 }
#                 else {
#                     return pagamento zero ( 71 examples )
#                     return procedência total ( 25 examples )
#                     return acordo ( 57 examples )
#                     return procedência parcial ( 18 examples )
#                 }
#             }
#             else {
#                 return pagamento zero ( 28 examples )
#                 return procedência total ( 6 examples )
#                 return acordo ( 35 examples )
#                 return procedência parcial ( 6 examples )
#             }
#         }
#         else {
#             if ( Cobertura Reclamada <= 3.5 ) {
#                 if ( Segmento <= 3.5 ) {
#                     if ( Segmento <= 1.5 ) {
#                         return pagamento zero ( 63 examples )
#                         return procedência total ( 10 examples )
#                         return acordo ( 49 examples )
#                         return procedência parcial ( 15 examples )
#                     }
#                     else {
#                         return pagamento zero ( 24 examples )
#                         return procedência total ( 5 examples )
#                         return acordo ( 11 examples )
#                         return procedência parcial ( 7 examples )
#                     }
#                 }
#                 else {
#                     return pagamento zero ( 11 examples )
#                     return acordo ( 6 examples )
#                 }
#             }
#             else {
#                 return pagamento zero ( 19 examples )
#                 return procedência total ( 8 examples )
#                 return acordo ( 17 examples )
#                 return procedência parcial ( 11 examples )
#             }
#         }
#     }
#     else {
#         if ( Segmento <= 2.5 ) {
#             if ( Segmento <= 1.5 ) {
#                 if ( Cobertura Reclamada <= 2.5 ) {
#                     if ( Cobertura Reclamada <= 1.5 ) {
#                         return pagamento zero ( 1 examples )
#                         return acordo ( 1 examples )
#                         return procedência parcial ( 1 examples )
#                     }
#                     else {
#                         return pagamento zero ( 85 examples )
#                         return procedência total ( 21 examples )
#                         return acordo ( 104 examples )
#                         return procedência parcial ( 76 examples )
#                     }
#                 }
#                 else {
#                     return pagamento zero ( 5 examples )
#                     return procedência total ( 1 examples )
#                     return acordo ( 5 examples )
#                     return procedência parcial ( 2 examples )
#                 }
#             }
#             else {
#                 if ( Cobertura Reclamada <= 1.5 ) {
#                     return acordo ( 1 examples )
#                 }
#                 else {
#                     if ( Cobertura Reclamada <= 3.0 ) {
#                         return pagamento zero ( 32 examples )
#                         return procedência total ( 8 examples )
#                         return acordo ( 36 examples )
#                         return procedência parcial ( 39 examples )
#                     }
#                     else {
#                         return procedência parcial ( 1 examples )
#                     }
#                 }
#             }
#         }
#         else {
#             return pagamento zero ( 23 examples )
#             return procedência total ( 1 examples )
#             return acordo ( 22 examples )
#             return procedência parcial ( 11 examples )
#         }
#     }
# }
# else {
#     if ( Cobertura Reclamada <= 3.5 ) {
#         if ( Cobertura Reclamada <= 1.5 ) {
#             if ( Mês Encerramento <= 1.5 ) {
#                 if ( Segmento <= 3.5 ) {
#                     if ( Segmento <= 1.5 ) {
#                         return pagamento zero ( 53 examples )
#                         return procedência total ( 83 examples )
#                         return acordo ( 45 examples )
#                         return procedência parcial ( 30 examples )
#                     }
#                     else {
#                         return pagamento zero ( 10 examples )
#                         return procedência total ( 15 examples )
#                         return acordo ( 4 examples )
#                         return procedência parcial ( 8 examples )
#                     }
#                 }
#                 else {
#                     return pagamento zero ( 1 examples )
#                     return acordo ( 1 examples )
#                 }
#             }
#             else {
#                 return procedência parcial ( 1 examples )
#             }
#         }
#         else {
#             return pagamento zero ( 3 examples )
#             return procedência parcial ( 3 examples )
#         }
#     }
#     else {
#         return procedência total ( 8 examples )
#         return acordo ( 2 examples )
#         return procedência parcial ( 3 examples )
#     }
# }

# %%
#dt.predict([[1, 2, 1, 1]])

# %%
test = pd.read_csv('/home/sbk2/Desktop/Zurich/Final/teste2.csv', decimal=',', encoding='utf-8')
pd.options.display.float_format = '{:.2f}'.format

teste = test[['Segmento','Motivo da Ação','Classificação da Contingência','Objeto', 'Status Encerramento']]
teste = teste.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)
teste = teste.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

teste['Segmento'] = teste['Segmento'].replace('life', 1)
teste['Segmento'] = teste['Segmento'].replace('gi', 2)

teste['Motivo da Ação'] = teste['Motivo da Ação'].replace('indenização parcial', 'sinistro liquidado parcialmente')
teste['Motivo da Ação'] = teste['Motivo da Ação'].replace(['notificação sem regulação','negado pré-analise','ctg reportada.','notificação não atendida'], 'outros')
teste['Motivo da Ação'] = teste['Motivo da Ação'].replace('sinistro negado', 1)
teste['Motivo da Ação'] = teste['Motivo da Ação'].replace('sinistro liquidado parcialmente', 2)
teste['Motivo da Ação'] = teste['Motivo da Ação'].replace('sinistro não avisado', 3)
teste['Motivo da Ação'] = teste['Motivo da Ação'].replace('sinistro liquidado', 4)
teste['Motivo da Ação'] = teste['Motivo da Ação'].replace('outros', 5)

teste = teste[teste['Classificação da Contingência'] != 'remoto' ]
teste = teste[teste['Classificação da Contingência'] != '0' ]
teste['Classificação da Contingência'] = teste['Classificação da Contingência'].replace('condenação', 1)
teste['Classificação da Contingência'] = teste['Classificação da Contingência'].replace('sucumbência', 2)

teste['Objeto'] = teste['Objeto'].replace('seguro acidentes pessoais', 'acidentes pessoais')
teste['Objeto'] = teste['Objeto'].replace('seguro de automóvel', 'seguro automóvel')
teste['Objeto'] = teste['Objeto'].replace(['cartão de crédito','seguro de saúde'], 'seguros diversos')
teste['Objeto'] = teste['Objeto'].replace(['seguro automóvel','seguro prestamista','seguro empresarial','previdência privada'], 'seguros diversos')

teste['Objeto'] = teste['Objeto'].replace('seguro de vida', 1)
teste['Objeto'] = teste['Objeto'].replace('seguro residencial', 2)
teste['Objeto'] = teste['Objeto'].replace('acidentes pessoais', 3)
teste['Objeto'] = teste['Objeto'].replace('seguros diversos', 4)

teste['Status Encerramento'] = teste['Status Encerramento'].replace('acordo', 0)
teste['Status Encerramento'] = teste['Status Encerramento'].replace('pagamento zero', 1)
teste['Status Encerramento'] = teste['Status Encerramento'].replace('procedência parcial', 2)
teste['Status Encerramento'] = teste['Status Encerramento'].replace('procedência total', 3)

teste = teste.dropna()
teste.head(15)
# Out:
#     Segmento  Motivo da Ação  Classificação da Contingência  Objeto  \
# 0          1            1.00                           1.00    1.00
# 1          1            1.00                           2.00    1.00
# 2          1            1.00                           1.00    1.00
# 3          2            2.00                           1.00    2.00
# 4          1            1.00                           1.00    1.00
# 5          1            2.00                           1.00    1.00
# 6          1            1.00                           1.00    1.00
# 7          1            1.00                           1.00    1.00
# 8          1            1.00                           2.00    1.00
# 9          1            1.00                           1.00    1.00
# 10         1            1.00                           1.00    1.00
# 11         1            1.00                           1.00    1.00
# 12         1            1.00                           1.00    1.00
# 13         1            2.00                           1.00    1.00
# 14         1            1.00                           1.00    1.00
#
#     Status Encerramento
# 0                     0
# 1                     0
# 2                     2
# 3                     1
# 4                     1
# 5                     2
# 6                     0
# 7                     2
# 8                     3
# 9                     3
# 10                    1
# 11                    0
# 12                    3
# 13                    2
# 14                    1

# %%
x_teste = teste[['Segmento','Motivo da Ação','Classificação da Contingência', 'Objeto']]
y_teste = teste[['Status Encerramento']]

print(x_teste)
# Out:
#       Segmento  Motivo da Ação  Classificação da Contingência  Objeto
# 0            1            1.00                           1.00    1.00
# 1            1            1.00                           2.00    1.00
# 2            1            1.00                           1.00    1.00
# 3            2            2.00                           1.00    2.00
# 4            1            1.00                           1.00    1.00
# 5            1            2.00                           1.00    1.00
# 6            1            1.00                           1.00    1.00
# 7            1            1.00                           1.00    1.00
# 8            1            1.00                           2.00    1.00
# 9            1            1.00                           1.00    1.00
# 10           1            1.00                           1.00    1.00
# 11           1            1.00                           1.00    1.00
# 12           1            1.00                           1.00    1.00
# 13           1            2.00                           1.00    1.00
# 14           1            1.00                           1.00    1.00
# 15           1            1.00                           1.00    1.00
# 16           1            3.00                           1.00    1.00
# 17           1            1.00                           1.00    1.00
# 19           1            2.00                           1.00    1.00
# 20           1            1.00                           1.00    1.00
# 21           1            1.00                           1.00    1.00
# 22           1            3.00                           1.00    1.00
# 23           1            1.00                           1.00    1.00
# 24           1            1.00                           1.00    1.00
# 25           1            1.00                           1.00    1.00
# 26           1            1.00                           2.00    1.00
# 27           1            1.00                           1.00    1.00
# 28           1            2.00                           1.00    1.00
# 29           1            1.00                           1.00    4.00
# 30           1            1.00                           1.00    1.00
# ...        ...             ...                            ...     ...
# 1123         1            1.00                           1.00    1.00
# 1124         1            1.00                           1.00    1.00
# 1125         1            2.00                           1.00    1.00
# 1126         1            1.00                           2.00    1.00
# 1127         1            1.00                           1.00    1.00
# 1128         1            3.00                           1.00    1.00
# 1129         1            3.00                           1.00    1.00
# 1130         1            1.00                           1.00    1.00
# 1131         2            1.00                           1.00    2.00
# 1132         1            1.00                           1.00    1.00
# 1133         1            1.00                           1.00    1.00
# 1134         1            1.00                           1.00    1.00
# 1135         1            2.00                           2.00    1.00
# 1136         1            2.00                           1.00    1.00
# 1137         1            3.00                           1.00    1.00
# 1138         1            1.00                           2.00    1.00
# 1139         1            1.00                           1.00    1.00
# 1140         1            4.00                           1.00    1.00
# 1141         1            3.00                           1.00    3.00
# 1142         1            1.00                           1.00    1.00
# 1143         1            1.00                           1.00    1.00
# 1144         1            3.00                           1.00    1.00
# 1145         1            1.00                           1.00    1.00
# 1146         1            1.00                           1.00    1.00
# 1147         1            1.00                           1.00    1.00
# 1148         1            1.00                           1.00    1.00
# 1149         1            1.00                           1.00    1.00
# 1150         1            1.00                           1.00    1.00
# 1151         1            3.00                           1.00    1.00
# 1152         1            1.00                           1.00    1.00
#
# [1120 rows x 4 columns]

# %%
y_pred = dt.predict(x_teste)
y_pred
# Out:
# array([2, 1, 2, ..., 2, 0, 2])

# %%
y_pred2 = rf.predict(x_teste)
y_pred2
# Out:
# array([2, 1, 2, ..., 2, 0, 2])

# %%
from sklearn.metrics import accuracy_score

print ('Accuracy is', accuracy_score(y_teste,y_pred)*100 , '%')
# Out:
# Accuracy is 17.410714285714285 %

# %%
final_abrir = pd.read_csv('/home/sbk2/Desktop/Zurich/Final/limpo_2.csv', decimal=',', encoding='utf-8')
pd.options.display.float_format = '{:.2f}'.format

final = final_abrir[['Segmento','Motivo da Ação','Classificação da Contingência','Objeto', 'Status Encerramento','Nº do processo']]
final = final.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)
final = final.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

final['Segmento'] = final['Segmento'].replace('life', 1)
final['Segmento'] = final['Segmento'].replace('gi', 2)

final['Motivo da Ação'] = final['Motivo da Ação'].replace('indenização parcial', 'sinistro liquidado parcialmente')
final['Motivo da Ação'] = final['Motivo da Ação'].replace(['notificação sem regulação','negado pré-analise','ctg reportada.','notificação não atendida'], 'outros')
final['Motivo da Ação'] = final['Motivo da Ação'].replace('sinistro negado', 1)
final['Motivo da Ação'] = final['Motivo da Ação'].replace('sinistro liquidado parcialmente', 2)
final['Motivo da Ação'] = final['Motivo da Ação'].replace('sinistro não avisado', 3)
final['Motivo da Ação'] = final['Motivo da Ação'].replace('sinistro liquidado', 4)
final['Motivo da Ação'] = final['Motivo da Ação'].replace('outros', 5)

final = final[final['Classificação da Contingência'] != 'remoto' ]
final = final[final['Classificação da Contingência'] != '0' ]
final['Classificação da Contingência'] = final['Classificação da Contingência'].replace('condenação', 1)
final['Classificação da Contingência'] = final['Classificação da Contingência'].replace('sucumbência', 2)

final['Objeto'] = final['Objeto'].replace('seguro acidentes pessoais', 'acidentes pessoais')
final['Objeto'] = final['Objeto'].replace('seguro de automóvel', 'seguro automóvel')
final['Objeto'] = final['Objeto'].replace(['cartão de crédito','seguro de saúde'], 'seguros diversos')
final['Objeto'] = final['Objeto'].replace(['seguro automóvel','seguro prestamista','seguro empresarial','previdência privada'], 'seguros diversos')

final['Objeto'] = final['Objeto'].replace('seguro de vida', 1)
final['Objeto'] = final['Objeto'].replace('seguro residencial', 2)
final['Objeto'] = final['Objeto'].replace('acidentes pessoais', 3)
final['Objeto'] = final['Objeto'].replace('seguros diversos', 4)

final['Status Encerramento'] = final['Status Encerramento'].replace('acordo', 0)
final['Status Encerramento'] = final['Status Encerramento'].replace('pagamento zero', 1)
final['Status Encerramento'] = final['Status Encerramento'].replace('procedência parcial', 2)
final['Status Encerramento'] = final['Status Encerramento'].replace('procedência total', 3)

final = final.dropna()

previsao_final = final['Nº do processo'] 

x_final = final[['Segmento','Motivo da Ação','Classificação da Contingência', 'Objeto']]

final['Previsao'] = dt.predict(x_final)

final['Nome'] = final['Previsao']
final['Nome'] = final['Nome'].replace(0, 'acordo')
final['Nome'] = final['Nome'].replace(1, 'pagamento zero')
final['Nome'] = final['Nome'].replace(2, 'procedência parcial')
final['Nome'] = final['Nome'].replace(3, 'procedência total')

print(final)
# Out:
#       Segmento  Motivo da Ação  Classificação da Contingência  Objeto  \
# 0            1            1.00                           1.00    1.00
# 1            1            1.00                           1.00    3.00
# 2            1            4.00                           1.00    3.00
# 3            1            1.00                           1.00    3.00
# 4            2            1.00                           1.00    2.00
# 5            2            1.00                           1.00    2.00
# 6            1            1.00                           1.00    1.00
# 7            1            1.00                           1.00    1.00
# 8            1            4.00                           1.00    1.00
# 9            1            4.00                           1.00    1.00
# 10           1            1.00                           1.00    1.00
# 11           1            1.00                           1.00    1.00
# 12           1            3.00                           1.00    1.00
# 13           1            1.00                           1.00    1.00
# 14           1            1.00                           1.00    1.00
# 15           1            1.00                           1.00    1.00
# 16           1            1.00                           1.00    1.00
# 17           1            1.00                           1.00    1.00
# 18           1            1.00                           1.00    1.00
# 20           1            1.00                           1.00    1.00
# 21           1            1.00                           1.00    1.00
# 22           2            4.00                           1.00    2.00
# 23           2            1.00                           1.00    2.00
# 24           1            1.00                           1.00    1.00
# 25           1            4.00                           1.00    1.00
# 26           1            1.00                           2.00    1.00
# 27           1            1.00                           1.00    1.00
# 30           1            3.00                           2.00    1.00
# 31           1            1.00                           2.00    1.00
# 32           1            3.00                           1.00    1.00
# ...        ...             ...                            ...     ...
# 4124         1            1.00                           1.00    1.00
# 4125         1            2.00                           1.00    1.00
# 4126         2            1.00                           1.00    2.00
# 4127         2            1.00                           1.00    2.00
# 4128         1            1.00                           1.00    3.00
# 4129         1            1.00                           1.00    3.00
# 4130         1            1.00                           1.00    3.00
# 4131         1            1.00                           1.00    3.00
# 4132         1            1.00                           1.00    3.00
# 4133         1            1.00                           1.00    3.00
# 4134         1            1.00                           1.00    4.00
# 4135         1            1.00                           1.00    1.00
# 4136         1            1.00                           1.00    1.00
# 4137         1            1.00                           1.00    1.00
# 4138         1            1.00                           1.00    1.00
# 4139         1            1.00                           1.00    1.00
# 4140         1            1.00                           1.00    1.00
# 4141         1            1.00                           1.00    1.00
# 4142         1            3.00                           2.00    1.00
# 4143         1            1.00                           2.00    1.00
# 4144         1            1.00                           2.00    1.00
# 4145         1            3.00                           1.00    1.00
# 4146         1            1.00                           1.00    1.00
# 4147         2            1.00                           1.00    2.00
# 4148         1            2.00                           1.00    1.00
# 4149         2            1.00                           1.00    2.00
# 4150         2            2.00                           1.00    2.00
# 4153         1            1.00                           1.00    3.00
# 4155         1            1.00                           1.00    1.00
# 4156         1            1.00                           2.00    1.00
#
#       Status Encerramento                    Nº do processo  Previsao  \
# 0                       0                 0194.08.0092805-5         2
# 1                       0         0029253-41.2015.8.19.0054         0
# 2                       1         1002046-96.2016.8.26.0223         0
# 3                       1         0027065-58.2016.8.19.0210         0
# 4                       1         1037751-94.2016.8.26.0114         2
# 5                       1         0084160-17.2015.8.13.0382         2
# 6                       2         1001332-48.2016.8.26.0123         2
# 7                       3         0706985-11.2015.8.02.0058         2
# 8                       1         1094560-83.2015.8.26.0100         2
# 9                       3                            740/05         2
# 10                      3         1001120-91.2015.8.26.0016         2
# 11                      1         1006648-88.2014.8.26.0292         2
# 12                      2         0469586-32.2015.8.19.0001         0
# 13                      1                         1838/2011         2
# 14                      0         0032794-41.2012.8.21.0019         2
# 15                      2         0005101-42.2012.8.19.0212         2
# 16                      2         0008480-63.2012.8.13.0145         2
# 17                      0                200.2012.070.520-3         2
# 18                      2              168.01.2011.001546-4         2
# 20                      3              405.01.2011.053238-7         2
# 21                      1              069.01.2011.000607-0         2
# 22                      0                   002.10.009778-4         0
# 23                      0                   008.10.800709-7         2
# 24                      1    0089540-20.2010.8.13.0245/0245         2
# 25                      3              242.01.2010.002540-0         2
# 26                      3                         208722006         1
# 27                      1         0006344-02.2011.8.26.0005         2
# 30                      3  223.02.2008.005760-3 (1174/2008)         1
# 31                      0    8.863/2006 ( 044.06.000.097-1)         1
# 32                      0                  024.10.304.589-4         0
# ...                   ...                               ...       ...
# 4124                    1              590.01.2010.009405-1         2
# 4125                    1              404.01.2011.003151-2         0
# 4126                    0                           2843/11         2
# 4127                    1              564.01.2011.046992-0         2
# 4128                    1         0001864-42.2014.8.26.0274         0
# 4129                    1              583.00.2011.125026-7         0
# 4130                    1              066.01.2011.007875-8         0
# 4131                    1              646.01.2012.000352-4         0
# 4132                    1              361.02.2011.002160-9         0
# 4133                    1              451.01.2012.028930-4         0
# 4134                    2                001/1.12.0209027-4         0
# 4135                    1         0432632-89.2012.8.19.0001         2
# 4136                    1         0001504-11.2014.8.26.0306         2
# 4137                    1         0000112-04.2014.8.26.0543         2
# 4138                    1                            244/11         2
# 4139                    1              348.01.2010.020894-1         2
# 4140                    1   297.01.2010.002663-9 (266/2010)         2
# 4141                    1  588.01.2009.002101-4 (1272/2009)         2
# 4142                    3                          281/2009         1
# 4143                    1                   075.08.015676-7         1
# 4144                    3                           1752009         1
# 4145                    1         1007141-83.2014.8.26.0577         0
# 4146                    1         0002581-81.2014.8.26.0362         2
# 4147                    1         1004868-97.2014.8.26.0362         2
# 4148                    1                           1995/10         0
# 4149                    2              296.01.2012.004147-0         2
# 4150                    1         3000002-92.2013.8.26.0185         3
# 4153                    1                             89/13         0
# 4155                    1                004/1.05.0007914-8         2
# 4156                    1    572.01.2007.006952-1 (1531/07)         1
#
#                      Nome
# 0     procedência parcial
# 1                  acordo
# 2                  acordo
# 3                  acordo
# 4     procedência parcial
# 5     procedência parcial
# 6     procedência parcial
# 7     procedência parcial
# 8     procedência parcial
# 9     procedência parcial
# 10    procedência parcial
# 11    procedência parcial
# 12                 acordo
# 13    procedência parcial
# 14    procedência parcial
# 15    procedência parcial
# 16    procedência parcial
# 17    procedência parcial
# 18    procedência parcial
# 20    procedência parcial
# 21    procedência parcial
# 22                 acordo
# 23    procedência parcial
# 24    procedência parcial
# 25    procedência parcial
# 26         pagamento zero
# 27    procedência parcial
# 30         pagamento zero
# 31         pagamento zero
# 32                 acordo
# ...                   ...
# 4124  procedência parcial
# 4125               acordo
# 4126  procedência parcial
# 4127  procedência parcial
# 4128               acordo
# 4129               acordo
# 4130               acordo
# 4131               acordo
# 4132               acordo
# 4133               acordo
# 4134               acordo
# 4135  procedência parcial
# 4136  procedência parcial
# 4137  procedência parcial
# 4138  procedência parcial
# 4139  procedência parcial
# 4140  procedência parcial
# 4141  procedência parcial
# 4142       pagamento zero
# 4143       pagamento zero
# 4144       pagamento zero
# 4145               acordo
# 4146  procedência parcial
# 4147  procedência parcial
# 4148               acordo
# 4149  procedência parcial
# 4150    procedência total
# 4153               acordo
# 4155  procedência parcial
# 4156       pagamento zero
#
# [4025 rows x 8 columns]

# %%
prediction = pd.DataFrame(final, columns=['Nº do processo','Nome']).to_csv('prediction.csv')
